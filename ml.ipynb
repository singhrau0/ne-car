# %%
import pandas as pd

# %%
df = pd.read_csv("encodeddata.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
make_encode = df[['Make','Make_encode']].drop_duplicates()

# %%
import numpy as np

# %%
g ={}

# %%
g['make_encode'] = np.array(make_encode)

# %%
make_encode.to_json("new.json")

# %%
make_encode.to_dict()
# Out:
# {'Make': {0: 'BMW',
#   17: 'Audi',
#   32: 'FIAT',
#   35: 'Mercedes-Benz',
#   64: 'Chrysler',
#   87: 'Nissan',
#   104: 'Volvo',
#   112: 'Mazda',
#   194: 'Mitsubishi',
#   294: 'Ferrari',
#   474: 'Alfa Romeo',
#   479: 'Toyota',
#   604: 'McLaren',
#   611: 'Maybach',
#   674: 'Pontiac',
#   736: 'Porsche',
#   800: 'Saab',
#   1137: 'GMC',
#   1171: 'Hyundai',
#   1189: 'Plymouth',
#   1192: 'Honda',
#   1287: 'Oldsmobile',
#   1300: 'Suzuki',
#   1331: 'Ford',
#   1367: 'Cadillac',
#   1426: 'Kia',
#   1452: 'Bentley',
#   1476: 'Chevrolet',
#   1610: 'Dodge',
#   1620: 'Lamborghini',
#   1650: 'Lincoln',
#   1747: 'Subaru',
#   1792: 'Volkswagen',
#   2116: 'Spyker',
#   2341: 'Buick',
#   2696: 'Acura',
#   2921: 'Rolls-Royce',
#   3030: 'Maserati',
#   3173: 'Lexus',
#   3520: 'Aston Martin',
#   3551: 'Land Rover',
#   3912: 'Lotus',
#   4269: 'Infiniti',
#   4893: 'Scion',
#   5202: 'Genesis',
#   5692: 'HUMMER',
#   6921: 'Tesla',
#   11362: 'Bugatti'},
# ...

# %%
make_encode=df[["Make","Make_encode"]].drop_duplicates()
model_encode=df[["Model","Model_encode"]].drop_duplicates()
enginefueltype=df[["Engine Fuel Type","Engine Fuel Type_encode"]].drop_duplicates()
transmissionType=df[["Transmission Type","Transmission Type_encode"]].drop_duplicates()
drivenwheels=df[["Driven_Wheels","Driven_Wheels_encode"]].drop_duplicates()	
vehiclesize=df[["Vehicle Size","Vehicle Size_encode"]].drop_duplicates()

# %%
model_encode
# Out:
#             Model  Model_encode
# 0      1 Series M             1
# 1        1 Series             0
# 17            100             2
# 32     124 Spider             3
# 35      190-Class             4
# ...           ...           ...
# 11890        Z4 M           899
# 11894          Z4           898
# 11903          Z8           900
# 11906         ZDX           901
# 11913      Zephyr           902
#
# [915 rows x 2 columns]

# %%
make_encode=df[['Make','Make_encode',]].drop_duplicates()

model_encode=df[['Model','Model_encode',]].drop_duplicates()

eft_encode=df[['Engine Fuel Type','Engine Fuel Type_encode',]].drop_duplicates()

tt_encode=df[['Transmission Type','Transmission Type_encode',]].drop_duplicates()

dw_encode=df[['Driven_Wheels','Driven_Wheels_encode',]].drop_duplicates()

vs_encode=df[['Vehicle Style','Vehicle Style_encode',]].drop_duplicates()

vsz_encode=df[['Vehicle Size','Vehicle Size_encode',]].drop_duplicates()

# %%
make_encode.to_json("make_encode.json")
model_encode.to_json("model_encode.json")
eft_encode.to_json("eft_encode.json")
tt_encode.to_json("tt_encode.json")
dw_encode.to_json("dw_encode.json")
vs_encode.to_json("vs_encode.json")
vsz_encode.to_json("vsz_encode.json")
