# %%
import pandas as pd

# %%
df = pd.read_json("new.json")

# %%
df['Make_encode'][df['Make']=='BMW'].values[0]

# %%
df

# %%
import pickle

# %%
pip install scikit-learn

# %%
with open('model.pkl','rb') as model:
    mlmodel = pickle.load(model)

# %%
mlmodel.get_feature_names_out()

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.isnull().sum()

# %%
df

# %%
df['Engine Fuel Type'].mode()

# %%
df['Engine Fuel Type'].fillna("regular unleaded",inplace=True)

# %%
df.isnull().sum()

# %%
df.drop(["Market Category"],axis = 1,inplace = True)

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/titanic_dataset.csv")

# %%
df

# %%
df.fillna(df['Age'].mean(),inplace = True)
df.fillna(df['Fare'].mean(),inplace = True)
df.drop("Cabin",axis = 1,inplace = True)

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace = True)

# %%
df.isnull().sum()

# %%
df

# %%
df['Gender'].value_counts()

# %%
df[df['Survived']==1]

# %%
# total percentage of people survived
(342*100)/891

# %%
df[(df["Gender"]=="male") & (df['Survived']==1)]

# %%
df['Pclass'].unique()

# %%
df[(df['Pclass']==3) & (df['Survived']==1)]

# %%
df['Pclass'].value_counts()

# %%
# 491 ----- 119
#

# %%
df

# %%
df.tail(2)

# %%
# iloc
# loc

# %%
df

# %%
df.loc[2:10:2,"PassengerId":"Gender":2]

# %%
df.iloc[2:11:2,0:5:2]

# %%
df

# %%
data = pd.DataFrame({"c1":[ i for i in range(100,300,2)],"c2":[i for i in range(101,301,2)],"c3":[i for i in range(101,301,2)]},index=[i for i in range(300,400)])

# %%
data.loc[300::2,:]

# %%
data.loc[300:310:2,"c1":"c3":2]

# %%
data.loc[32:34,:"c1"]

# %%
data.loc[[319,328,378],["c1","c3"]]

# %%
data.loc[[i for i in range(300,400) if i%2==0 and i%4==0 and i%6!=0 ]]

# %%
[i for i in range(300,400) if i%2==0 and i%4==0 and i%6!=0 ]

# %%
for i in range(300,400):
    if i%2==0 and i%4==0 and i%6!=0:
        print(i)

# %%
data

# %%
data.loc[data["c2"]==103,['c2']] = 1003

# %%
data

# %%
df.loc[df["Gender"]=="female",["Gender"]]="FEMALE"

# %%
df

# %%
df.isnull().sum()

# %%
df.loc[df['Age'].isnull(),['Age']]=28.0

# %%
df[~(df['Cabin'].isnull())]

# %%
df1 = pd.DataFrame({"Fruits":['Apple','kiwi','orange'],"Quantity":[10,20,30]},index =['a','b','c'] )

# %%
df1.iloc[0:2]

# %%
df1.loc['a':'b']

# %%
df2 = pd.DataFrame({
    "A":[i for i in range(10,200,2)],
    "B":[i for i in range(11,200,2)]
    },
    index = [i for i in range(1000,1095)]
)

# %%
df2.describe(include=all)

# %%
df.describe(include='all')

# %%
df[['Gender']].describe(include='all')

# %%
df.describe(include='all')

# %%
df[['Embarked','Gender']].describe()

# %%
df['Age'].mean()

# %%
df.describe()

# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Wheather-Prediction-march-batch/main/Datasets/raw_data/train.csv")

# %%
data.isnull().sum()

# %%
data['Precip Type'].mode()

# %%
data['Precip Type'].fillna("rain",inplace=True)

# %%
data.isnull().sum()

# %%
data.dtypes

# %%
data.info()

# %%
import datetime as dt

# %%
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'],utc=True)

# %%
data.dtypes

# %%
import datetime as dt

# %%
data['Formatted Date'].dt.year

# %%
data

# %%
data['month name'] = data['Formatted Date'].dt.month_name()

# %%
data

# %%
data['Formatted Date'] = data['Formatted Date'].astype('datetime64[ns, UTC]')

# %%
data.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                    int64
# Visibility (km)                         float64
# Cloud Cover                               int64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
data['necol'] = data['Humidity']**2

# %%
data.rename(columns={"Humidity":"hp","Summary":"sm"},inplace=True)

# %%
data
# Out:
#                  Formatted Date             sm Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 94263 2016-05-09 17:00:00+00:00  Partly Cloudy        rain        19.972222
# 94264 2016-05-09 18:00:00+00:00  Partly Cloudy        rain        17.816667
# 94265 2016-05-09 19:00:00+00:00  Partly Cloudy        rain        13.938889
# 94266 2016-05-09 20:00:00+00:00  Partly Cloudy        rain        12.733333
# 94267 2016-05-09 21:00:00+00:00  Partly Cloudy        rain        13.038889
#
# ...

# %%
sum1 = 0
for i in data['Temperature (C)'].values:
    sum1 = sum1+i
print(sum1/len(data['Temperature (C)'].values))
# Out:
# 11.949453626311598

# %%
data['Temperature (C)'].values
# Out:
# array([ 9.47222222,  9.35555556,  9.37777778, ..., 13.93888889,
#        12.73333333, 13.03888889])

# %%
from functools import reduce

# %%
reduce(lambda x,y:x+y,data['Temperature (C)'].values)/len(data['Temperature (C)'].values)
# Out:
# 11.949453626311598

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived'].replace({0:"Not Survived",1:"Survived"},inplace=True)

# %%
df
# Out:
#      PassengerId      Survived  Pclass  \
# 0              1  Not Survived       3
# 1              2      Survived       1
# 2              3      Survived       3
# 3              4      Survived       1
# 4              5  Not Survived       3
# ..           ...           ...     ...
# 886          887  Not Survived       2
# 887          888      Survived       1
# 888          889  Not Survived       3
# 889          890      Survived       1
# 890          891  Not Survived       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
x = "hello r new r"

# %%
x.replace('r','$')
# Out:
# 'hello $ new $'

# %%
x = 'Hello i am new'

# %%
x.replace("Hello",'hey')
# Out:
# 'hey i am new'

# %%
df['Name'] = df['Name'].str.replace("r","$")

# %%
df
# Out:
#      PassengerId      Survived  Pclass  \
# 0              1  Not Survived       3
# 1              2      Survived       1
# 2              3      Survived       3
# 3              4      Survived       1
# 4              5  Not Survived       3
# ..           ...           ...     ...
# 886          887  Not Survived       2
# 887          888      Survived       1
# 888          889  Not Survived       3
# 889          890      Survived       1
# 890          891  Not Survived       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              B$aund, M$. Owen Ha$$is    male  22.0      1
# 1    Cumings, M$s. John B$adley (Flo$ence B$iggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Fut$elle, M$s. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, M$. William Hen$y    male  35.0      0
# ...

# %%
data = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Wheather-Prediction-march-batch/main/Datasets/raw_data/train.csv")

# %%
data['Precip Type'].fillna('rain',inplace=True)

# %%
data['Formatted Date'] = data['Formatted Date'].astype('datetime64[ns, UTC]')

# %%
import datetime as dt

# %%
data['monthname'] = data['Formatted Date'].dt.month_name()

# %%
data
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 94263 2016-05-09 17:00:00+00:00  Partly Cloudy        rain        19.972222
# 94264 2016-05-09 18:00:00+00:00  Partly Cloudy        rain        17.816667
# 94265 2016-05-09 19:00:00+00:00  Partly Cloudy        rain        13.938889
# 94266 2016-05-09 20:00:00+00:00  Partly Cloudy        rain        12.733333
# 94267 2016-05-09 21:00:00+00:00  Partly Cloudy        rain        13.038889
#
# ...

# %%
data[['year','Humidity']].groupby('year').max()
# Out:
#       Humidity
# year
# 2005      0.89
# 2006      1.00
# 2007      1.00
# 2008      1.00
# 2009      1.00
# 2010      1.00
# 2011      1.00
# 2012      1.00
# 2013      1.00
# 2014      1.00
# 2015      1.00
# 2016      1.00

# %%
d1 = data[data['Precip Type']=='rain']

# %%
d1[['year','Precip Type']].groupby('year').count().sort_values(by = 'Precip Type',ascending=False)
# Out:
#       Precip Type
# year
# 2014         8272
# 2015         8132
# 2007         8015
# 2008         7985
# 2009         7742
# 2013         7735
# 2012         7485
# 2006         7468
# 2010         7454
# 2011         7362
# 2016         5905
# 2005            1

# %%
[['year','Precip Type']]
# Out:
#        year Precip Type
# 0      2006        rain
# 1      2006        rain
# 2      2006        rain
# 3      2006        rain
# 4      2006        rain
# ...     ...         ...
# 94263  2016        rain
# 94264  2016        rain
# 94265  2016        rain
# 94266  2016        rain
# 94267  2016        rain
#
# [83556 rows x 2 columns]

# %%
data[['Precip Type','Humidity']].groupby("Precip Type").max()
# Out:
#              Humidity
# Precip Type
# rain              1.0
# snow              1.0

# %%
data[['year','monthname','Wind Speed (km/h)']].groupby(['year','monthname']).mean().sort_values(by = 'Wind Speed (km/h)',ascending=False)
# Out:
#                 Wind Speed (km/h)
# year monthname
# 2005 December           17.114300
# 2009 March              16.882365
#      February           14.799302
# 2008 March              14.622479
# 2010 March              14.610252
# ...                           ...
# 2013 August              7.971859
# 2015 December            7.950262
#      August              7.419027
# 2006 July                7.193908
# 2011 November            6.871637
#
# [131 rows x 1 columns]

# %%
data
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 94263 2016-05-09 17:00:00+00:00  Partly Cloudy        rain        19.972222
# 94264 2016-05-09 18:00:00+00:00  Partly Cloudy        rain        17.816667
# 94265 2016-05-09 19:00:00+00:00  Partly Cloudy        rain        13.938889
# 94266 2016-05-09 20:00:00+00:00  Partly Cloudy        rain        12.733333
# 94267 2016-05-09 21:00:00+00:00  Partly Cloudy        rain        13.038889
#
# ...

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Cloud Cover',
#        'Pressure (millibars)', 'Daily Summary', 'year', 'monthname'],
#       dtype='object')

# %%
gt = data[['year','monthname','Temperature (C)']]

# %%
gk = gt.groupby(['year','monthname'])

# %%
x = gk.mean()

# %%
x.sort_values(by = ['year','Temperature (C)'],ascending=False)
# Out:
#                 Temperature (C)
# year monthname
# 2016 July             22.786208
#      August           21.434726
#      June             21.309784
#      May              16.324836
#      April            13.345062
# ...                         ...
# 2006 March             4.559274
#      December          2.218220
#      February         -0.065394
#      January          -1.677942
# 2005 December          0.577778
#
# [131 rows x 1 columns]

# %%
h = data[['year','Wind Speed (km/h)','Humidity']]

# %%
t = h.groupby('year')

# %%
t.agg({'Wind Speed (km/h)':['mean','min','max','sum'],'Humidity':['mean','min','max','sum']})
# Out:
#      Wind Speed (km/h)                                 Humidity              \
#                   mean      min      max          sum      mean   min   max
# year
# 2005         17.114300  17.1143  17.1143      17.1143  0.890000  0.89  0.89
# 2006         10.189128   0.0000  45.9333   89256.7578  0.767349  0.26  1.00
# 2007         10.824162   0.0000  63.8526   94819.6620  0.689647  0.13  1.00
# 2008         11.304172   0.0000  55.9314   99295.8484  0.701239  0.00  1.00
# 2009         11.507326   0.0000  48.3000  100804.1769  0.707247  0.00  1.00
# 2010         11.014343   0.0000  46.2070   96749.9876  0.796861  0.29  1.00
# 2011          9.898596   0.0000  49.3948   86711.7020  0.736008  0.20  1.00
# 2012         11.264745   0.0000  45.0800   98949.5213  0.689513  0.00  1.00
# 2013         10.970036   0.0000  50.1354   96097.5190  0.754197  0.15  1.00
# 2014         10.501276   0.0000  54.8849   91959.6741  0.748571  0.18  1.00
# ...
